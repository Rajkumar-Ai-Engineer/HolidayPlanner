# %%
import googlemaps
from datetime import datetime
client = googlemaps.Client(key="AIzaSyAtSb74FX71cdV6MMRVxcatjgs-40rS1ek")

# %%
source = "Paganatham,karur,Tamilnadu"
destination = "Trichy,Tamilnadu"

# %%
result = client.distance_matrix(origins=source,destinations=destination,mode="driving",departure_time=datetime.now())

# %%
distance_text = result["rows"][0]["elements"][0]["distance"]["text"]
distance_value = result["rows"][0]["elements"][0]["distance"]["value"] / 1000  # meters to km

print("Distance:", distance_text)
print("Distance in KM:", distance_value)
# Out:
# Distance: 92.0 km
# Distance in KM: 91.981

# %%
# 2.Tavily
